# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df.groupby("Country").sum().sort_values("HDI Rank (2021)")["HDI Rank (2021)"].reset_index()
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_20980\834318854.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Country").sum().sort_values("HDI Rank (2021)")["HDI Rank (2021)"].reset_index()
#                       Country  HDI Rank (2021)
# 0                     Somalia              0.0
# 1                 North Korea              0.0
# 2                      Monaco              0.0
# 3                       Nauru              0.0
# 4                 Switzerland              1.0
# ..                        ...              ...
# 190                   Burundi            187.0
# 191  Central African Republic            188.0
# 192                     Niger            189.0
# 193                      Chad            190.0
# 194               South Sudan            191.0
#
# ...

# %%
df["Human Development Groups"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot: ylabel='Human Development Groups'>

# %%
sns.heatmap(pd.crosstab(df.Continent,df["Human Development Groups"]),annot=True)
# Out:
# <AxesSubplot: xlabel='Human Development Groups', ylabel='Continent'>

# %%
sns.countplot(x=df["Continent"],hue=df["Human Development Groups"],palette="BuPu")
# Out:
# <AxesSubplot: xlabel='Continent', ylabel='count'>

# %%
sns.stripplot(x=df["Continent"],y=df["Gross National Income Per Capita (1991)"])
sns.stripplot(x=df["Continent"],y=df["Gross National Income Per Capita (1992)"])
sns.stripplot(x=df["Continent"],y=df["Gross National Income Per Capita (1993)"])
# Out:
# <AxesSubplot: xlabel='Continent', ylabel='Gross National Income Per Capita (1991)'>

# %%
b=[]
for i in range(7,39):
    b.append((df.columns[i][-5:-1]))

# %%
df.groupby("Country").mean().reset_index().plot()
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_20980\1408069616.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Country").mean().reset_index().plot()
# <AxesSubplot: >

# %%
df.groupby("Continent").mean().reset_index().plot()
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_20980\3346582177.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Continent").mean().reset_index().plot()
# <AxesSubplot: >

# %%
j=0
for i in df.Country:
    a[i]=df.iloc[j,7:39]
    j=j+1
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_20980\2856849619.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   a[i]=df.iloc[j,7:39]
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_20980\2856849619.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   a[i]=df.iloc[j,7:39]
# ...

# %%
sns.heatmap(df.pivot_table(index="Human Development Groups",columns="UNDP Developing Regions",values="Gross National Income Per Capita (2021)"),annot=True)
# Out:
# <AxesSubplot: xlabel='UNDP Developing Regions', ylabel='Human Development Groups'>

# %%
import numpy as np

# %%
for i in df.iloc[:,7:32].columns:
    df[i].fillna(df[i].mean())

# %%
df.isna().sum()
# Out:
# ISO3                                        0
# Country                                     0
# Continent                                   0
# Hemisphere                                  0
# Human Development Groups                    4
# UNDP Developing Regions                    44
# HDI Rank (2021)                             4
# Gross National Income Per Capita (1990)    11
# Gross National Income Per Capita (1991)    11
# Gross National Income Per Capita (1992)    11
# Gross National Income Per Capita (1993)    11
# Gross National Income Per Capita (1994)    11
# Gross National Income Per Capita (1995)     4
# Gross National Income Per Capita (1996)     4
# Gross National Income Per Capita (1997)     4
# Gross National Income Per Capita (1998)     4
# Gross National Income Per Capita (1999)     4
# Gross National Income Per Capita (2000)     4
# Gross National Income Per Capita (2001)     4
# Gross National Income Per Capita (2002)     4
# ...

# %%
sns.scatterplot(x=df["Continent"],y=df["Gross National Income Per Capita (2021)"],size=df["Gross National Income Per Capita (2021)"])
# Out:
# <AxesSubplot: xlabel='Continent', ylabel='Gross National Income Per Capita (2021)'>

# %%
sns.lineplot(x=df["Gross National Income Per Capita (2002)"],y=df["Gross National Income Per Capita (2021)"],hue=df["Human Development Groups"])
# Out:
# <AxesSubplot: xlabel='Gross National Income Per Capita (2002)', ylabel='Gross National Income Per Capita (2021)'>

# %%
sns.boxplot(x=df["Continent"],y=df["Gross National Income Per Capita (2002)"])
# Out:
# <AxesSubplot: xlabel='Continent', ylabel='Gross National Income Per Capita (2002)'>

# %%
sns.boxplot(x=df["Continent"],y=df["Gross National Income Per Capita (2021)"])
# Out:
# <AxesSubplot: xlabel='Continent', ylabel='Gross National Income Per Capita (2021)'>

# %%
sns.boxplot(x=df["Continent"],y=df["Gross National Income Per Capita (2021)"])
# Out:
# <AxesSubplot: xlabel='Continent', ylabel='Gross National Income Per Capita (2021)'>

# %%
x=df.iloc[:,7:]
x
# Out:
#      Gross National Income Per Capita (1990)  \
# 0                                2684.550019
# 1                                4845.706901
# 2                                4742.215529
# 3                               43773.146500
# 4                              102433.136000
# ..                                       ...
# 190                                 0.000000
# 191                              2730.788444
# 192                             10900.726060
# 193                              2015.484747
# 194                              2660.896738
#
#      Gross National Income Per Capita (1991)  \
# 0                                2276.289409
# 1                                5405.349257
# 2                                3358.087827
# 3                               43175.147600
# 4                               96250.290360
# ..                                       ...
# 190                                 0.000000
# 191                              2574.032279
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier

# %%
from sklearn.metrics import accuracy_score

# %%
df.fillna(0,inplace=True)

# %%
y=df["Continent"]
xtr,xts,ytr,yts=train_test_split(x,y,random_state=0,test_size=0.3)
accuracy_score(GradientBoostingClassifier(n_estimators=30,max_features=34).fit(xtr,ytr).predict(xts),yts)
# Out:
# 0.5254237288135594

# %%
from sklearn.model_selection import Ridge
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 from sklearn.model_selection import Ridge
#
# ImportError: cannot import name 'Ridge' from 'sklearn.model_selection' (c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\__init__.py)

# %%
from sklearn.linear_model import LogisticRegression,Ridge

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
y=df["Continent"]
xtr,xts,ytr,yts=train_test_split(x,y,random_state=0,test_size=0.3)
accuracy_score(LogisticRegression(C=1000,n_jobs=4).fit(xtr,ytr).predict(xts),yts)
# Out:
# 0.3559322033898305

# %%
confusion_matrix(LogisticRegression(C=1000,n_jobs=4).fit(xtr,ytr).predict(xts),yts)
# Out:
# array([[0, 0, 1, 0, 0],
#        [4, 1, 2, 4, 1],
#        [9, 7, 8, 2, 1],
#        [1, 2, 0, 9, 0],
#        [3, 0, 1, 0, 3]], dtype=int64)

# %%
df["Human Development Groups"].value_counts()
# Out:
# Very High    66
# High         49
# Medium       44
# Low          32
# Nan           4
# Name: Human Development Groups, dtype: int64

# %%
df["Human Development Groups"][df["Human Development Groups"]==0]="Nan"
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_20980\77915755.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Human Development Groups"][df["Human Development Groups"]==0]="Nan"

# %%
y=df["Human Development Groups"]
xtr,xts,ytr,yts=train_test_split(x,y,random_state=0,test_size=0.3)
accuracy_score(LogisticRegression(C=1000,n_jobs=4).fit(xtr,ytr).predict(xts),yts)
# Out:
# 0.3728813559322034

# %%
classification_report(LogisticRegression(C=1000,n_jobs=4).fit(xtr,ytr).predict(xts),yts)
# Out:
# '              precision    recall  f1-score   support\n\n      Africa       0.00      0.00      0.00         1\n     America       0.10      0.08      0.09        12\n        Asia       0.67      0.30      0.41        27\n      Europe       0.60      0.75      0.67        12\n     Oceania       0.60      0.43      0.50         7\n\n    accuracy                           0.36        59\n   macro avg       0.39      0.31      0.33        59\nweighted avg       0.52      0.36      0.40        59\n'

# %%
y=df["Continent"]
xtr,xts,ytr,yts=train_test_split(x,y,random_state=0,test_size=0.3)
accuracy_score(RandomForestClassifier(n_estimators=30,max_features=32).fit(xtr,ytr).predict(xts),yts)
# Out:
# 0.5254237288135594

# %%
y=df["Continent"]
xtr,xts,ytr,yts=train_test_split(x,y,random_state=0,test_size=0.3)
accuracy_score(GradientBoostingClassifier(n_estimators=30,max_features=34).fit(xtr,ytr).predict(xts),yts)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 39 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ISO3                                     195 non-null    object
#  1   Country                                  195 non-null    object
#  2   Continent                                195 non-null    object
#  3   Hemisphere                               195 non-null    object
#  4   Human Development Groups                 191 non-null    object
#  5   UNDP Developing Regions                  151 non-null    object
#  6   HDI Rank (2021)                          191 non-null    float64
#  7   Gross National Income Per Capita (1990)  184 non-null    float64
#  8   Gross National Income Per Capita (1991)  184 non-null    float64
#  9   Gross National Income Per Capita (1992)  184 non-null    float64
# ...

# %%
df["UNDP Developing Regions"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot: ylabel='UNDP Developing Regions'>

# %%
df=pd.read_csv("./Gross National Income Per Capita.csv")
df
# Out:
#     ISO3               Country Continent           Hemisphere  \
# 0    AFG           Afghanistan      Asia  Northern Hemisphere
# 1    AGO                Angola    Africa  Southern Hemisphere
# 2    ALB               Albania    Europe  Northern Hemisphere
# 3    AND               Andorra    Europe  Northern Hemisphere
# 4    ARE  United Arab Emirates      Asia  Northern Hemisphere
# ..   ...                   ...       ...                  ...
# 190  WSM                 Samoa   Oceania  Southern Hemisphere
# 191  YEM                 Yemen      Asia  Northern Hemisphere
# 192  ZAF          South Africa    Africa  Southern Hemisphere
# 193  ZMB                Zambia    Africa  Southern Hemisphere
# 194  ZWE              Zimbabwe    Africa  Southern Hemisphere
#
#     Human Development Groups UNDP Developing Regions  HDI Rank (2021)  \
# 0                        Low                      SA            180.0
# 1                     Medium                     SSA            148.0
# ...
