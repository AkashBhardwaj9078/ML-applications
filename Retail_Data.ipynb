# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("./retail_sales_dataset.csv")

# %%
sns.relplot(x=df["Date"],y=df["Age"],hue=df["Product Category"],style=df["Gender"],size=df["Total Amount"])

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
sns.barplot(x=df["Gender"],y=df["Total Amount"],hue=df["Product Category"])
# Out:
# <AxesSubplot: xlabel='Gender', ylabel='Total Amount'>

# %%
sns.pairplot(df)

# %%
sns.histplot(df["Total Amount"])
# Out:
# <AxesSubplot: xlabel='Total Amount', ylabel='Count'>

# %%
sns.swarmplot(x=df["Product Category"],y=df["Total Amount"],hue=df["Gender"])
# Out:
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 30.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 33.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3543: UserWarning: 31.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot: xlabel='Product Category', ylabel='Total Amount'>
# ...

# %%
sns.violinplot(x=df["Product Category"],y=df["Total Amount"],hue=df["Gender"],split=True)
# Out:
# <AxesSubplot: xlabel='Product Category', ylabel='Total Amount'>

# %%
color=["Red","Green","Blue"]
k=0
for i in df["Product Category"].unique():
    p=df[df["Product Category"]==i]
    
    sns.histplot(p["Age"],label=i,bins=20)
    
    
    k=k+1
    
plt.legend()

# %%
for i in df["Product Category"].unique():
    p=df[df["Product Category"]==i]
    p.

# %%
color=["Red","Green","Blue"]
k=0
for i in df["Product Category"].unique():
    p=df[df["Product Category"]==i]
    
    sns.distplot(p["Total Amount"],label=i)
    
    
    k=k+1
    
plt.legend()
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_15388\4099396312.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(p["Total Amount"],label=i)
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_15388\4099396312.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.jointplot(x=df["Age"],y=df["Total Amount"],hue=df["Product Category"],palette="winter",size=df["Price per Unit"])

# %%
for i in df["Product Category"].unique():
    p=df[df["Product Category"]==i]
    sns.distplot(p["Quantity"],label=i)
plt.legend()
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_15388\3369455809.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(p["Quantity"],label=i)
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_15388\3369455809.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
plt.figure(figsize=(12,6))
a=df.groupby(df["Product Category"]).sum()["Quantity"]
b=df.groupby(df["Product Category"]).sum()["Total Amount"]
plt.subplot(1,2,1)
plt.pie(a,labels=["Beauty","Clothing","Electronics"],autopct='%0.2f')
plt.title("Quantity")
plt.subplot(1,2,2)
plt.pie(b,labels=["Beauty","Clothing","Electronics"],autopct='%0.2f')
plt.title("Total Amount")
# Out:
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_15388\2672165187.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   a=df.groupby(df["Product Category"]).sum()["Quantity"]
# C:\Users\NEERA KUMARI\AppData\Local\Temp\ipykernel_15388\2672165187.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   b=df.groupby(df["Product Category"]).sum()["Total Amount"]
# Text(0.5, 1.0, 'Total Amount')

# %%
sns.violinplot(x=df["Product Category"],y=df["Age"],hue=df["Gender"],split=True)
# Out:
# <AxesSubplot: xlabel='Product Category', ylabel='Age'>

# %%
sns.violinplot(x=df["Product Category"],y=df["Quantity"],hue=df["Gender"],split=True)
# Out:
# <AxesSubplot: xlabel='Product Category', ylabel='Quantity'>

# %%
sns.barplot(x=df["Product Category"],y=df["Quantity"],hue=df["Gender"])
# Out:
# <AxesSubplot: xlabel='Product Category', ylabel='Quantity'>

# %%
sns.jointplot(x=df["Price per Unit"],y=df["Total Amount"],size=df["Age"],hue=df["Product Category"])

# %%
x=df[["Quantity","Total Amount","Price per Unit","Age"]].values

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay,classification_report

# %%
from sklearn.preprocessing import

# %%
y=df["Gender"]
xtr,xts,ytr,yts=train_test_split(x,y,random_state=1,test_size=0.2)
accuracy_score(LogisticRegressionCV().fit(xtr,ytr).predict(xts),yts)
# Out:
# 0.495

# %%
y=df["Product Category"]
xtr,xts,ytr,yts=train_test_split(x,y,random_state=1,test_size=0.2)
accuracy_score(LogisticRegressionCV().fit(xtr,ytr).predict(xts),yts)
# Out:
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
x=df.select_dtypes("float").iloc[:,0:4]

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("./car_purchasing.csv",encoding='latin')

# %%
x=df.select_dtypes("float").values

# %%
y=df["car purchase amount"]
# Out:
# 0      35321.45877
# 1      45115.52566
# 2      42925.70921
# 3      67422.36313
# 4      55915.46248
#           ...
# 495    48901.44342
# 496    31491.41457
# 497    64147.28888
# 498    45442.15353
# 499    45107.22566
# Name: car purchase amount, Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split
xtr,xts,ytr,yts=train_test_split(x,y,random_state=1,test_size=0.2)

# %%
import tensorflow as tf 
from tensorflow import keras

mod=tf.keras.models.Sequential(
    keras.layers.Dense(10,activation="softmax",input_dim=4),
    keras.layers.Dense(12,activation='relu')
    
)
    
mod.compile(loss="mean_squared_error",metrics=["mean_absolute_error"],optimizer="Adam")

# %%
ytr
# Out:
# 238    42997.16761
# 438    43898.27330
# 475    55167.37361
# 58     38147.81018
# 380    47715.96049
#           ...
# 255    29092.13110
# 72     41903.65171
# 396    65592.22012
# 235    50702.18103
# 37     10092.22509
# Name: car purchase amount, Length: 400, dtype: float64

# %%
mod.fit(xtr,ytr,epochs=3)
# Out:
# Epoch 1/3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 mod.fit(xtr,ytr,epochs=3)
#
# File c:\Users\NEERA KUMARI\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File C:\Users\NEERAK~1\AppData\Local\Temp\__autograph_generated_fileq53abul2.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ...

# %%
df
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...
